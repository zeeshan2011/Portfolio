# %% [markdown]
# # Stack Overflow data

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 85)
pd.set_option('display.max_columns', 85)

# %%
df = pd.read_csv(r"C:\Users\pshan\Desktop\pandas new\2020 data\survey_results_public.csv", index_col = 'Respondent')
df_schema = pd.read_csv(r"C:\Users\pshan\Desktop\pandas new\2020 data\survey_results_schema.csv", index_col ='Column' )

# %%
df_schema
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
df.shape
# Out:
# (64461, 60)

# %%
#counting the values of column hobbyist
df['Hobbyist'].value_counts()
# Out:
# Yes    50388
# No     14028
# Name: Hobbyist, dtype: int64

# %%
df['Hobbyist'].head(100).value_counts()
# Out:
# Yes    75
# No     25
# Name: Hobbyist, dtype: int64

# %%
#counting the values of column hobbyist for specific country germany
df[df['Country'] == 'Germany']['Hobbyist'].value_counts()
# Out:
# Yes    3249
# No      641
# Name: Hobbyist, dtype: int64

# %%
df_schema.loc['NEWDevOpsImpt', 'QuestionText']
# Out:
# 'How important is the practice of DevOps to scaling software development?'

# %%
# sorting the index alphabaticlly
df_schema.sort_index(inplace = True)

# sorting the index from bottom to top
#df_schema.sort_index(ascending = False, inplace = True)

# %%
df_schema
# Out:
#                                                                    QuestionText
# Column
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# DatabaseDesireNextYear        Which database environments have you done exte...
# DatabaseWorkedWith            Which database environments have you done exte...
# DevType                       Which of the following describe you? Please se...
# ...

# %%
# filtering the data for the people who know python 
df['LanguageWorkedWith'].str.contains('Python')
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4          NaN
# 5        False
#          ...
# 64858      NaN
# 64867     True
# 64898      NaN
# 64925    False
# 65112    False
# Name: LanguageWorkedWith, Length: 64461, dtype: object

# %%
df_python = df[df['LanguageWorkedWith'].str.contains('Python') == True]

# %%
#filtreing out the data with referene to their sexuality
df_python['Sexuality'].value_counts()
# Out:
# Straight / Heterosexual                                  17742
# Bisexual                                                   939
# Gay or Lesbian                                             463
# Bisexual;Straight / Heterosexual                           132
# Queer                                                      129
# Bisexual;Queer                                             111
# Gay or Lesbian;Queer                                        54
# Straight / Heterosexual;Queer                               25
# Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer       22
# Bisexual;Gay or Lesbian                                     22
# Bisexual;Gay or Lesbian;Queer                               14
# Bisexual;Straight / Heterosexual;Queer                       7
# Bisexual;Gay or Lesbian;Straight / Heterosexual              6
# Gay or Lesbian;Straight / Heterosexual                       5
# Name: Sexuality, dtype: int64

# %%
#filtring the data about the people living in Germany who knows python
df_python[df_python['Country'] == 'Germany']
# Out:
#                                         MainBranch Hobbyist   Age Age1stCode  \
# Respondent
# 60          I am a student who is learning to code      Yes   NaN         14
# 111         I am a student who is learning to code      Yes  25.0         20
# 120                 I am a developer by profession      Yes  24.0         15
# 148                 I am a developer by profession       No  34.0         13
# 166                 I am a developer by profession      Yes  28.0          9
# ...                                            ...      ...   ...        ...
# 19751                                          NaN      Yes  24.0         11
# 30238                                          NaN      Yes  31.0         18
# 36284                                          NaN      Yes   NaN         11
# 52163                                          NaN      Yes   NaN         14
# 56263                                          NaN      Yes   NaN         14
#
# ...

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...
