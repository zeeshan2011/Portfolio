# %%
import pandas as pd

# %%
pd.set_option('display.max_rows' , 80)
pd.set_option('display.max_columns', 80)

# %%
df = pd.read_csv(r"C:\Users\pshan\Desktop\pandas new\2020 data\survey_results_public.csv", index_col = 'Respondent')
df_schema = pd.read_csv(r"C:\Users\pshan\Desktop\pandas new\2020 data\survey_results_schema.csv", index_col ='Column' )

# %%
df_schema
# Out:
#                                                                    QuestionText
# Column
# Respondent                    Randomized respondent ID number (not in order ...
# MainBranch                    Which of the following options best describes ...
# Hobbyist                                                Do you code as a hobby?
# Age                           What is your age (in years)? If you prefer not...
# Age1stCode                    At what age did you write your first line of c...
# CompFreq                       Is that compensation weekly, monthly, or yearly?
# CompTotal                     What is your current total compensation (salar...
# ConvertedComp                 Salary converted to annual USD salaries using ...
# Country                                                      Where do you live?
# CurrencyDesc                  Which currency do you use day-to-day? If your ...
# CurrencySymbol                Which currency do you use day-to-day? If your ...
# ...

# %%
# getting the highest salaries
df['ConvertedComp'].sort_values(ascending = False).head(50)
# Out:
# Respondent
# 33254    2000000.0
# 4475     2000000.0
# 47615    2000000.0
# 47680    2000000.0
# 59974    2000000.0
# 1624     2000000.0
# 1629     2000000.0
# 47791    2000000.0
# 4538     2000000.0
# 47949    2000000.0
# 47592    2000000.0
# 26330    2000000.0
# 17610    2000000.0
# 60024    2000000.0
# 48098    2000000.0
# 26262    2000000.0
# 32377    2000000.0
# 60666    2000000.0
# 4657     2000000.0
# 4686     2000000.0
# 48289    2000000.0
# 46711    2000000.0
# 18078    2000000.0
# 18059    2000000.0
# 18032    2000000.0
# 27623    2000000.0
# 18031    2000000.0
# 46562    2000000.0
# 17900    2000000.0
# 59916    2000000.0
# 1589     2000000.0
# 62040    2000000.0
# 27314    2000000.0
# 46863    2000000.0
# 4791     2000000.0
# 34805    2000000.0
# 19324    2000000.0
# 13548    2000000.0
# 26181    2000000.0
# 17392    2000000.0
# 27999    2000000.0
# 25009    2000000.0
# 3948     2000000.0
# 25181    2000000.0
# 32497    2000000.0
# 25138    2000000.0
# 62660    2000000.0
# ...

# %%
df[['Country','ConvertedComp', 'LanguageWorkedWith']].sort_values(by = 'ConvertedComp', ascending = False).head(50)
# Out:
#                   Country  ConvertedComp  \
# Respondent
# 33254       United States      2000000.0
# 4475        United States      2000000.0
# 47615       United States      2000000.0
# 47680       United States      2000000.0
# 59974       United States      2000000.0
# 1624        United States      2000000.0
# 1629        United States      2000000.0
# 47791       United States      2000000.0
# 4538        United States      2000000.0
# 47949       United States      2000000.0
# 47592       United States      2000000.0
# 26330       United States      2000000.0
# 17610       United States      2000000.0
# 60024       United States      2000000.0
# 48098       United States      2000000.0
# 26262       United States      2000000.0
# 32377       United States      2000000.0
# 60666       United States      2000000.0
# 4657        United States      2000000.0
# 4686        United States      2000000.0
# 48289       United States      2000000.0
# ...

# %%
#getting results for specific countries using filter
countries = ['United States', 'India', 'Germany','Pakistan']
country_filt = df['Country'].isin(countries)

# %%
df.loc[country_filt, ['Country','ConvertedComp', 'LanguageWorkedWith']].sort_values(by = 'ConvertedComp', ascending = False).head()
# Out:
#                   Country  ConvertedComp  \
# Respondent
# 59916       United States      2000000.0
# 28298       United States      2000000.0
# 29403       United States      2000000.0
# 29359       United States      2000000.0
# 60032       United States      2000000.0
#
#                                            LanguageWorkedWith
# Respondent
# 59916                                  C#;HTML/CSS;JavaScript
# 28298              C#;HTML/CSS;Java;JavaScript;SQL;TypeScript
# 29403               C#;C++;HTML/CSS;JavaScript;SQL;TypeScript
# 29359         Assembly;Bash/Shell/PowerShell;C;C++;Python;SQL
# 60032       Bash/Shell/PowerShell;Java;JavaScript;SQL;Type...

# %%
language_filter = df['LanguageWorkedWith'].str.contains('Python', na = False)

# %%
#gettign the data for specific countries where people working with python , using 2 filters 
df.loc[country_filt & language_filter,['Country', 'ConvertedComp','LanguageWorkedWith']]
# Out:
#                   Country  ConvertedComp  \
# Respondent
# 8           United States       116000.0
# 17          United States        79000.0
# 22                  India            NaN
# 27          United States            NaN
# 40          United States            NaN
# ...                   ...            ...
# 54361       United States            NaN
# 54757               India            NaN
# 56263             Germany            NaN
# 58498       United States            NaN
# 63077       United States            NaN
#
#                                            LanguageWorkedWith
# Respondent
# 8                                                  Python;SQL
# 17                      C#;HTML/CSS;JavaScript;Python;SQL;VBA
# 22                                                Java;Python
# 27                Bash/Shell/PowerShell;C;C++;Java;Python;SQL
# 40                C;C#;C++;HTML/CSS;JavaScript;PHP;Python;SQL
# ...                                                       ...
# ...

# %%
# Out:
# Respondent
# 1        False
# 2        False
# 3         True
# 4          NaN
# 5        False
#          ...
# 64858      NaN
# 64867     True
# 64898      NaN
# 64925    False
# 65112    False
# Name: LanguageWorkedWith, Length: 64461, dtype: object
