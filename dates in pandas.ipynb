# %%
import pandas as pd

# %%
d_parser = lambda x : pd.datetime.strptime(x , '%Y-%m-%d %I-%p')

# %%
df = pd.read_csv(r'C:\Users\pshan\Desktop\pandas new\ETH_1h.csv', parse_dates = ['Date'], date_parser = d_parser)
# Out:
# C:\Users\pshan\AppData\Local\Temp\ipykernel_19080\1399177037.py:1: FutureWarning: The pandas.datetime class is deprecated and will be removed from pandas in a future version. Import from datetime module instead.
#   d_parser = lambda x : pd.datetime.strptime(x , '%Y-%m-%d %I-%p')

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     Day of Weak
# Date
# 2020-03-13 20:00:00      Friday
# ...

# %%
# to read the day name from date
df.loc[0, 'Date'].day_name()
# Out:
# 'Friday'

# %%
# to change the date format  
df['Date'] = pd.to_datetime(df['Date'], format = '%Y-%m-%d %I-%p')

# %%
df.loc[0,'Date'].day_name()
# Out:
# 'Friday'

# %%
df['Date'].dt.day_name()
# Out:
# 0          Friday
# 1          Friday
# 2          Friday
# 3          Friday
# 4          Friday
#            ...
# 23669    Saturday
# 23670    Saturday
# 23671    Saturday
# 23672    Saturday
# 23673    Saturday
# Name: Date, Length: 23674, dtype: object

# %%
df['Day of Weak'] = df['Date'].dt.day_name()

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#       Day of Weak
# ...

# %%
df['Date'].min()
# Out:
# Timestamp('2017-07-01 11:00:00')

# %%
df['Date'].max()
# Out:
# Timestamp('2020-03-13 20:00:00')

# %%
df['Date'].max() - df['Date'].min()
# Out:
# Timedelta('986 days 09:00:00')

# %%
filt = df['Date'] > '2020'

# %%
df[filt]
# Out:
#                     Date  Symbol    Open    High     Low   Close      Volume  \
# 0    2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1    2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2    2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3    2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4    2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                  ...     ...     ...     ...     ...     ...         ...
# 1743 2020-01-01 05:00:00  ETHUSD  129.56  129.94  129.47  129.83   232163.70
# 1744 2020-01-01 04:00:00  ETHUSD  129.57  130.00  129.50  129.56   702786.82
# 1745 2020-01-01 03:00:00  ETHUSD  130.37  130.44  129.38  129.57   496704.23
# 1746 2020-01-01 02:00:00  ETHUSD  130.14  130.50  129.91  130.37   396315.72
# 1747 2020-01-01 01:00:00  ETHUSD  128.34  130.14  128.32  130.14   635419.40
#
#      Day of Weak
# 0         Friday
# ...

# %%
df.set_index('Date', inplace = True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
#                     Day of Weak
# Date
# 2020-03-13 20:00:00      Friday
# ...

# %%
# now data extraction becomes very simple
df.loc['2019']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     Day of Weak
# Date
# 2019-12-31 23:00:00     Tuesday
# ...

# %%
# df for an year
df['2019-01': '2019-12']
# Out:
#                      Symbol    Open    High     Low   Close      Volume  \
# Date
# 2019-12-31 23:00:00  ETHUSD  128.33  128.69  128.14  128.54   440678.91
# 2019-12-31 22:00:00  ETHUSD  128.38  128.69  127.95  128.33   554646.02
# 2019-12-31 21:00:00  ETHUSD  127.86  128.43  127.72  128.38   350155.69
# 2019-12-31 20:00:00  ETHUSD  127.84  128.34  127.71  127.86   428183.38
# 2019-12-31 19:00:00  ETHUSD  128.69  128.69  127.60  127.84  1169847.84
# ...                     ...     ...     ...     ...     ...         ...
# 2019-01-01 04:00:00  ETHUSD  130.75  133.96  130.74  131.96  2791135.37
# 2019-01-01 03:00:00  ETHUSD  130.06  130.79  130.06  130.75   503732.63
# 2019-01-01 02:00:00  ETHUSD  130.79  130.88  129.55  130.06   838183.43
# 2019-01-01 01:00:00  ETHUSD  131.62  131.62  130.77  130.79   434917.99
# 2019-01-01 00:00:00  ETHUSD  130.53  131.91  130.48  131.62  1067136.21
#
#                     Day of Weak
# Date
# 2019-12-31 23:00:00     Tuesday
# ...

# %%
#getting the mean values for the year 2019
df['2019-01':'2019-12'].mean()
# Out:
# C:\Users\pshan\AppData\Local\Temp\ipykernel_19080\3255048567.py:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df['2019-01':'2019-12'].mean()
# Open         180.752257
# High         181.766612
# Low          179.656623
# Close        180.752030
# Volume    936000.875187
# dtype: float64

# %%
df['2019-01':'2019-12'].describe()
# Out:
#               Open         High          Low        Close        Volume
# count  8760.000000  8760.000000  8760.000000  8760.000000  8.760000e+03
# mean    180.752257   181.766612   179.656623   180.752030  9.360009e+05
# std      50.634473    51.121336    50.071579    50.634703  1.510428e+06
# min     101.300000   101.700000   100.150000   101.300000  0.000000e+00
# 25%     141.120000   141.657500   140.717500   141.120000  2.409484e+05
# 50%     173.460000   174.275000   172.595000   173.460000  4.640788e+05
# 75%     209.047500   210.155000   207.762500   209.047500  1.023272e+06
# max     355.310000   364.490000   348.840000   355.310000  2.988731e+07

# %%
# high value for a single day
df.loc['2020-01-01']['High'].max()
# Out:
# 132.68

# %%
# resample data on daily basis
df['High'].resample('D').max()
# Out:
# Date
# 2017-07-01    279.99
# 2017-07-02    293.73
# 2017-07-03    285.00
# 2017-07-04    282.83
# 2017-07-05    274.97
#                ...
# 2020-03-09    208.65
# 2020-03-10    206.28
# 2020-03-11    202.98
# 2020-03-12    195.64
# 2020-03-13    148.00
# Freq: D, Name: High, Length: 987, dtype: float64

# %%
highs = df['High'].resample('D').max()
highs['2020-01-01']
# Out:
# 132.68

# %%
lows = df['Low'].resample('D').min()

# %%
import matplotlib as plt

# %%
highs['2017'].plot()
lows['2017'].plot()
# Out:
# <Axes: xlabel='Date'>

# %%
df.resample('D').agg({ 'High' : 'max', 'Low' : 'min', 'Close' : 'mean', 'Volume' : 'sum'})
# Out:
#               High     Low       Close        Volume
# Date
# 2017-07-01  279.99  253.23  265.284615  2.858402e+07
# 2017-07-02  293.73  255.70  269.782500  5.226229e+07
# 2017-07-03  285.00  273.07  278.882083  3.501635e+07
# 2017-07-04  282.83  265.00  276.743333  3.010991e+07
# 2017-07-05  274.97  252.67  265.025833  4.315016e+07
# ...            ...     ...         ...           ...
# 2020-03-09  208.65  189.85  200.818333  9.131404e+07
# 2020-03-10  206.28  195.17  201.577500  3.727352e+07
# 2020-03-11  202.98  181.00  195.910417  4.547683e+07
# 2020-03-12  195.64  101.22  152.763333  1.800737e+08
# 2020-03-13  148.00   90.00  124.060476  1.442618e+08
#
# [987 rows x 4 columns]

# %%
new_df = df.resample('D').agg({ 'High' : 'max', 'Low' : 'min', 'Close' : 'mean'})

# %%
new_df.loc['2017'].plot()
# Out:
# <Axes: xlabel='Date'>
